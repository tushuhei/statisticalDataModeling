# %% [markdown]
# データの取り込みと外観

# %%
load("data.rdata")
print(data)
# Out:
#  [1] 2 2 4 6 4 5 2 3 1 2 0 4 3 3 3 3 4 2 7 2 4 3 3 3 4 3 7 5 3 1 7 6 4 6 5 2 4 7
# [39] 2 2 6 2 4 5 4 5 1 3 2 3

# %%
length(data)
# Out:
# [1] 50

# %% [markdown]
# さらに、データの概観を見たい場合は summary() が便利。

# %%
summary(data)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00    3.00    3.56    4.75    7.00

# %% [markdown]
# 度数分布表

# %%
table(data)
# Out:
# data
#  0  1  2  3  4  5  6  7
#  1  3 11 12 10  5  4  4

# %%
hist(data, breaks=seq(-0.5, 9.5, 1))
# Out:
# Error in file(con, "rb"):  コネクションを開くことができません
# Plot with title “Histogram of data”

# %%
var(data)
# Out:
# [1] 2.986122

# %%
sd(data)
# Out:
# [1] 1.72804

# %%
sqrt(var(data))
# Out:
# [1] 1.72804

# %% [markdown]
# ひとまず、カウントデータを扱うにはポアソン分布が良いらしいという前提に立って、ポアソン分布を描写してみる。

# %%
y <- 0:9
prob <- dpois(y, lambda=3.56)
plot(y, prob, type="b", lty=2)
# Out:
# Error in file(con, "rb"):  コネクションを開くことができません
# plot without title

# %% [markdown]
# 重ねて描写すると・・・ひとまず当てはまっているっぽいなあ

# %%
hist(data, breaks=seq(-0.5, 9.5, 1))
lines(y, length(data) * prob, type="b", lty=2)
# Out:
# Error in file(con, "rb"):  コネクションを開くことができません
# Plot with title “Histogram of data”

# %% [markdown]
# 尤度について理解するために、いろいろ描いてみよう。

# %%
logL <- function(m) sum(dpois(data, m, log=TRUE))
lambda <- seq(2, 5, 0.1)
plot(lambda, sapply(lambda, logL), type="l")
# Out:
# Error in file(con, "rb"):  コネクションを開くことができません
# plot without title
